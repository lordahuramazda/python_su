# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sci
from astropy.io import fits
from astropy.io import ascii

# %%
a = np.mean([2,4,6,8])
b=[2,4,6,8]
a = np.mean(b)
c=[34, 40, 56, 67]
plt.figure() 
plt.plot(b,c) 
plt.plot(b,c,ls='', color='red', marker='o')

m, inter = np.polyfit(b,c,1)
x = np.linspace(1,8,10)
# y = np.linspace(20,70,10)
print(x)
print(m)
print(inter)
plt.plot(x, (m*x + inter), ls='--', c='gray', lw=1)
# Out:
# [1.         1.77777778 2.55555556 3.33333333 4.11111111 4.88888889
#  5.66666667 6.44444444 7.22222222 8.        ]
# 5.749999999999999
# 20.5

# %%
f = fits.open("C:/Users/Georgi/Downloads/NGC_3660_I_IIIaJ_dss1.fits")
f.info()
im=f[0].data
hdr=f[0].header
print(hdr)
plt.figure()
plt.imshow(im, cmap='magma', vmin=5689, vmax=19900)
# Out:
# Filename: C:/Users/Georgi/Downloads/NGC_3660_I_IIIaJ_dss1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     106   (283, 283)   int16
# ...
